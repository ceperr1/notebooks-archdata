# %% [markdown]
# # Using the Portable Antiquities Scheme API
#
# This activity is based on the notebook developed by ODAT and script by Daniel Pett [Fitzwilliam Museum](fitzmuseum.cam.ac.uk), who designed and built the PAS database and API The original notebook can be found in this forked repository.
#
# The [Portable Antiquities Scheme](https://finds.org.uk/about) provides an open access database of finds in support of the Treasury Act. The PAS records finds discovered by the public, outside of excavation, in England and Wales. The data available on the database can be accessed by anyone, but exact findspots are only available to credentialed researchers. The current data consist of almost 1.5 million objects that often contain visual media in the form of photographs, illustrations, or 3D models, as well as linked data. This model of public–professional collaboration, coupled with an open access dissemination strategy, has proven productive. The PAS lists close to 150 PhD dissertations that have used their data, as well as over 700 total research projects.
#
# You've already used Python to connect to the Open Context API, but here we'll use R and try to retrieve data using the PAS API. Since you've already go through the process with using an API, try to notice any similarities or differences between using Python and R.

# %% [markdown]
# 1. First bring in two packages in R.
#
# `library(jsonlite)`
#
# `library(RCurl)`

# %%
library(jsonlite)

library(RCurl)
# Out:
# Loading required package: bitops

# %% [markdown]
# 2. We're going to create a variable that will act as the base URL for PAS. This will be used later in the exercise.
#
# `base <- 'https://finds.org.uk/'`

# %%
base <- 'https://finds.org.uk/'

# %% [markdown]
# 3. Now we'll set up the query that will set the parameters of the data we want to access. We want to access all of the __Gold__ objects from the __Bronze Age__ that have __Images__. Before we go through the R code let's check the source data we're trying to access. Go to the [PAS database](https://finds.org.uk/database) and search "Gold" - you'll have close to 24K results. Limit the query on the right side to "Bronze Age" which will limit the results to about 4,300. Click on "Only results with images: On" - 385 results. These are the data you're going to access. If you click on the json linke at the bottom of the screen under "Other formats:" you'll see how the data is actually structured "behind the scenes" and how we'll retrive it.
#
# `url <-"https://finds.org.uk/database/search/results/q/gold/broadperiod/BRONZE+AGE/thumbnail/1/format/json"`

# %%
url <-"https://finds.org.uk/database/search/results/q/gold/broadperiod/BRONZE+AGE/thumbnail/1/format/json"

# %% [markdown]
# 4. We'll set up a variable that goes to the url (our query parameters in PAS) and gets the data.
#
# `json <- fromJSON(url)`

# %%
json <- fromJSON(url)

# %% [markdown]
# 5. Let's look at the first part of the data we've retrived.
#
# `head(json)`

# %%
head(json)
# Out:
# $meta
# $meta$currentPage
# [1] 1
#
# $meta$totalResults
# [1] 387
#
# $meta$resultsPerPage
# [1] 20
#
#
# $results
#    findIdentifier     id    old_findID      objecttype broadperiod
# 1    finds-990381 990381   WMID-0328FD    FLAT AXEHEAD  BRONZE AGE
# 2    finds-973486 973486    PAS-35C8A8          RIBBON  BRONZE AGE
# 3    finds-971661 971661   CORN-38B306    FLAT AXEHEAD  BRONZE AGE
# 4    finds-968920 968920   WMID-CF81FB    FLAT AXEHEAD  BRONZE AGE
# 5    finds-966940 966940   CORN-5491C3    FLAT AXEHEAD  BRONZE AGE
# 6    finds-962778 962778 LANCUM-C6B5FC            TORC  BRONZE AGE
# 7    finds-961873 961873   NMGW-47D2BB           HOARD  BRONZE AGE
# 8    finds-961742 961742   WMID-349A3E    FLAT AXEHEAD  BRONZE AGE
# 9    finds-961057 961057     BH-B6C885            TORC  BRONZE AGE
# 10   finds-959406 959406   BERK-B58065          RIBBON  BRONZE AGE
# 11   finds-958543 958543    IOW-65AD93        BRACELET  BRONZE AGE
# 12   finds-957243 957243    GLO-92912E       JEWELLERY  BRONZE AGE
# 13   finds-948587 948587   HAMP-DBAD3A            TORC  BRONZE AGE
# 14   finds-943923 943923   WILT-788C7B PENANNULAR RING  BRONZE AGE
# 15   finds-941113 941113    WAW-FC5599          BROOCH  BRONZE AGE
# 16   finds-940092 940092    NLM-57BC11        BRACELET  BRONZE AGE
# 17   finds-940073 940073    NLM-572E82           SPEAR  BRONZE AGE
# 18   finds-936844 936844    SUR-EFB639 PENANNULAR RING  BRONZE AGE
# 19   finds-935510 935510   SUSS-5B32DE PENANNULAR RING  BRONZE AGE
# 20   finds-928814 928814   KENT-D83432           INGOT  BRONZE AGE
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 7  1. Gold penannular bar bracelet fragment - Type 4B \n\nDimensions: surviving length 25.7mm; bar width 5.7mm; bar thickness 4mm; head width 9.8mm; head thickness 8.3mm; weight 7.36g.\n\nThis is a terminal fragment of a gold bar bracelet with a D-shape section. The bar expands abruptly to a solid, outwardly expanding flat terminal, also with a D-section. On the flat terminal face there is a slight penannular shaped hollow 0.5-1.0mm wide running around the sides and outer margins of the terminal. This is inset parallel with and approximately 0.5mm from the outer edge of the terminal face. The bar has been deliberately broken pre-deposition with a 'pinched' break, suggesting it was chiselled or cut, rather than bent and snapped. There is also one chisel mark on the flat face of the bar, which is close to the break and likely represents a failed impact mark. There are numerous and pronounced dents and impressed tool marks on the surface of the bracelet, which appear to be ancient, linked either with the forming of the bracelet or representing deliberate damage to the bracelet immediately prior to burial of the hoard.\n\n2. Copper alloy pin head or bracelet terminal fragment\n\nDimensions: surviving length 20.2mm; shaft diameter (below head) 4.8 x 5.2mm; shaft diameter (at break) 3.6 x 3.2mm; surviving head depth 11.5mm; surviving head width 10.2mm; weight 2.33g.\n\nThis is a fragment of a circular-section bar of bronze that expands at one end to an incomplete terminal or head. The head/terminal is concave with a convex underside and was probably originally circular. Below the head/terminal the shaft is appears to have been decorated with at least three horizontal ribs, which are now very worn and shallow, and separated by at least two shallow grooves. The shaft appears to taper slightly, but degradation to the surface makes this difficult to discern.\n\nFragmentation has occurred around the circumference of the head/terminal so no original edge survives, and the object has broken across the bar/shaft in prehistory. This breakage is coupled with damage to the surface of the bronze, which is consistently patinated. The object is covered in an uneven brown patina that is delaminated in patches, particularly around the edges.\n\n3. Copper alloy penannular bracelet terminal fragment (possibly once part of bracelet fragment 4)\n\nDimensions: surviving curved length 35.2mm; shaft diameter (at break) 3.4 x 2.7mm; surviving head diameter 9.3x8.1mm; weight 3.23g.\n\nThis is a fragment of a bracelet with a circular-section bar, gently expanding to a roughly oval terminal. The terminal is incomplete, and there is a prominent lateral ridge down the otherwise flat terminal. This ridge may be casting flash. The overall piece is curved, indicating it once formed part of a bracelet. As this fragment was found associated with possible bracelet fragment No. 4, below, it is possible that these fragments were once part of the same single bracelet, although no conjoin can now be established, as the break points on both fragments are worn and eroded.\n\nThere are small patches of an uneven brown patina surviving, particularly around the terminal, but much of the original surface has delaminated, revealing green corrosion.\n\n4. Copper alloy incomplete possible bracelet (possibly once part of bracelet fragment 3)\n\nDimensions: bent length 45mm; maximum bar diameter 4.3x5mm; min. bar diameter 3.6x1.8mm; weight 7.6g.\n\nThis is a bronze bar, bent into a rough U-shape, with a rounded section, now heavily eroded so as to be inconsistent in diameter and section shape along the length. Where original surfaces survive, there is an angular, slightly projecting casting flash evident on both interior and exterior sides of the hoop. Both ends are broken, though one expands slightly, which might indicate this was approaching a terminal end. At one point, the bar has been deliberately and differentially bent out of shape, compressing the surviving ends out of shap ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
#    treasure      TID fromsubperiod tosubperiod preservation preservationTerm
# 1        NA     <NA>            NA          NA           NA             <NA>
# 2         1 2017T798            NA          NA           NA             <NA>
# 3        NA     <NA>             1           1            4         Corroded
# 4        NA     <NA>             1           1           NA             <NA>
# 5        NA     <NA>             1           1            4         Corroded
# 6         1 2019T645            NA          NA           NA             <NA>
# 7         1 2016TW18             3          NA           NA             <NA>
# 8        NA     <NA>             1           1           NA             <NA>
# 9         1 2019T651            NA          NA            1             Fair
# 10        1 2019T574             2           3           NA             <NA>
# 11        1 2019T588             3           3            2             Good
# 12        1 2019T537             3           1           NA             <NA>
# 13        1 2019T356             2           2           NA             <NA>
# 14        1 2019T253             2           2           NA             <NA>
# 15       NA     <NA>             3           3            2             Good
# 16        1 2019T188             3           3            2             Good
# 17       NA     <NA>             2           3            2             Good
# 18        1  2019T87             2           3           NA             <NA>
# 19        1 2018T771            NA          NA           NA             <NA>
# 20        1 2018T937            NA          NA           NA             <NA>
#    subperiodFrom subperiodTo note               currentLocation
# 1           <NA>        <NA>   NA                          <NA>
# 2           <NA>        <NA>   NA                          <NA>
# 3          Early       Early   NA                          <NA>
# 4          Early       Early    1                          <NA>
# 5          Early       Early   NA                          <NA>
# 6           <NA>        <NA>   NA                          <NA>
# 7           Late        <NA>    1              Brecknock Museum
# 8          Early       Early   NA                          <NA>
# 9           <NA>        <NA>   NA                          <NA>
# 10        Middle        Late   NA                          <NA>
# 11          Late        Late    1 Returned to finder, 16/1/2020
# 12          Late       Early    1                          <NA>
# 13        Middle      Middle   NA                          <NA>
# 14        Middle      Middle   NA                          <NA>
# 15          Late        Late   NA                          <NA>
# 16          Late        Late    1                          <NA>
# 17        Middle        Late    1                          <NA>
# 18        Middle        Late    1                          <NA>
# 19          <NA>        <NA>   NA                          <NA>
# 20          <NA>        <NA>   NA                          <NA>
#    secondaryMaterial secondaryMaterialTerm secondaryMaterialBM       knownas
# 1                 NA                  <NA>                  NA          <NA>
# 2                 NA                  <NA>                  NA          <NA>
# 3                 NA                  <NA>                  NA          <NA>
# 4                 NA                  <NA>                  NA          <NA>
# 5                 NA                  <NA>                  NA          <NA>
# 6                 NA                  <NA>                  NA          <NA>
# 7                 23                  Gold               10892          <NA>
# 8                 NA                  <NA>                  NA          <NA>
# 9                 NA                  <NA>                  NA          <NA>
# 10                NA                  <NA>                  NA        Inkpen
# 11                NA                  <NA>                  NA          <NA>
# 12                NA                  <NA>                  NA     Cotswolds
# 13                NA                  <NA>                  NA          <NA>
# 14                NA                  <NA>                  NA Whitchurch CP
# 15                NA                  <NA>                  NA          <NA>
# 16                NA                  <NA>                  NA    near Brigg
# 17                14                  Wood               11988    near Brigg
# 18                 7          Copper alloy               10627          <NA>
# 19                NA                  <NA>                  NA    Upton Grey
# 20                NA                  <NA>                  NA        Elsted
#                                                otherRef diameter height
# 1                                                  <NA>       NA     NA
# 2                                                  <NA>       NA     NA
# 3                                                  <NA>       NA     NA
# 4                                                  <NA>       NA     NA
# 5                                                  <NA>       NA     NA
# 6                                                  <NA>       NA     NA
# 7                                                  <NA>       NA     NA
# 8                                                  <NA>       NA     NA
# 9                                                  <NA>       NA     NA
# 10                                                 <NA>       NA     NA
# 11                                        IOW2019-1-151       NA     NA
# 12                                                 <NA>       NA     NA
# 13 Hampshire Cultural Trust Object Entry Form WINCM 780      8.9     NA
# 14                                            SSWM 5434     13.9     NA
# 15                                             Birm 623       NA   26.2
# 16                                             NLM41579       NA     NA
# 17                                             NLM41578     22.6     NA
# 18                                                 <NA>       NA    6.8
# 19                                                 <NA>       NA   14.0
# 20                                                 <NA>       NA     NA
#                                                                 subClassification
# 1                                                                            <NA>
# 2                                                                            <NA>
# 3                                                                            <NA>
# 4                                                                            <NA>
# 5                                                                            <NA>
# 6                                                                            <NA>
# 7                                                                            <NA>
# 8                                                                            <NA>
# 9                                                                            <NA>
# 10                                                                           <NA>
# 11                                                                           <NA>
# 12                                                                           <NA>
# 13                                                                           <NA>
# 14                                                                           <NA>
# 15                                                                           <NA>
# 16                                                                           <NA>
# 17                                                                           <NA>
# 18 Gold face made from wires soldered together plates in triangular cross-section
# 19                                                                           <NA>
# 20                                                                           <NA>
#
# $facets
# $facets$objectType
# $facets$objectType$`PENANNULAR RING`
# [1] 128
#
# $facets$objectType$BRACELET
# [1] 31
#
# $facets$objectType$HOARD
# [1] 30
#
# $facets$objectType$`FLAT AXEHEAD`
# [1] 27
#
# $facets$objectType$RIBBON
# [1] 25
#
# $facets$objectType$TORC
# [1] 25
#
# $facets$objectType$`UNIDENTIFIED OBJECT`
# [1] 18
#
# $facets$objectType$BEAD
# [1] 14
#
# $facets$objectType$INGOT
# [1] 13
#
# $facets$objectType$JEWELLERY
# [1] 7
#
# $facets$objectType$ARMLET
# [1] 6
#
# $facets$objectType$PALSTAVE
# [1] 6
#
# $facets$objectType$`SOCKETED AXEHEAD`
# [1] 6
#
# $facets$objectType$ROD
# [1] 5
#
# $facets$objectType$PENDANT
# [1] 4
#
# $facets$objectType$AXE
# [1] 3
#
# $facets$objectType$KNIFE
# [1] 3
#
# $facets$objectType$LUNULA
# [1] 3
#
# $facets$objectType$MOUNT
# [1] 3
#
# $facets$objectType$RING
# [1] 3
#
# $facets$objectType$SPEAR
# [1] 3
#
# $facets$objectType$SWORD
# [1] 3
#
# $facets$objectType$AXEHEAD
# [1] 2
#
# $facets$objectType$DAGGER
# [1] 2
#
# $facets$objectType$PIN
# [1] 2
#
# $facets$objectType$SHEET
# [1] 2
#
# $facets$objectType$WIRE
# [1] 2
#
# $facets$objectType$ANVIL
# [1] 1
#
# $facets$objectType$BROOCH
# [1] 1
#
# $facets$objectType$BULLA
# [1] 1
#
# $facets$objectType$CAPE
# [1] 1
#
# $facets$objectType$CUP
# [1] 1
#
# $facets$objectType$DIADEM
# [1] 1
#
# $facets$objectType$`DRESS FASTENER (UNKNOWN)`
# [1] 1
#
# $facets$objectType$`EAR RING`
# [1] 1
#
# $facets$objectType$GOUGE
# [1] 1
#
# $facets$objectType$`METAL WORKING DEBRIS`
# [1] 1
#
# $facets$objectType$SHIELD
# [1] 1
#
#
# $facets$county
# $facets$county$Hampshire
# [1] 37
#
# $facets$county$Cornwall
# [1] 25
#
# $facets$county$Kent
# [1] 22
#
# $facets$county$Essex
# [1] 20
#
# $facets$county$`Isle of Wight`
# [1] 20
#
# $facets$county$Norfolk
# [1] 20
#
# $facets$county$Wiltshire
# [1] 16
#
# $facets$county$`West Sussex`
# [1] 15
#
# $facets$county$Staffordshire
# [1] 14
#
# $facets$county$Dorset
# [1] 13
#
# $facets$county$Oxfordshire
# [1] 10
#
# $facets$county$Warwickshire
# [1] 10
#
# $facets$county$Buckinghamshire
# [1] 9
#
# $facets$county$Suffolk
# [1] 9
#
# $facets$county$`West Berkshire`
# [1] 9
#
# $facets$county$`County of Herefordshire`
# [1] 8
#
# $facets$county$Shropshire
# [1] 8
#
# $facets$county$Cumbria
# [1] 7
#
# $facets$county$`East Riding of Yorkshire`
# [1] 7
#
# $facets$county$Leicestershire
# [1] 7
#
# $facets$county$Lincolnshire
# [1] 7
#
# $facets$county$Cambridgeshire
# [1] 6
#
# $facets$county$Gloucestershire
# [1] 5
#
# $facets$county$Somerset
# [1] 5
#
# $facets$county$Surrey
# [1] 5
#
# $facets$county$`the Vale of Glamorgan`
# [1] 5
#
# $facets$county$Devon
# [1] 4
#
# $facets$county$`East Sussex`
# [1] 4
#
# $facets$county$Northumberland
# [1] 4
#
# $facets$county$Nottinghamshire
# [1] 4
#
# $facets$county$Wrexham
# [1] 4
#
# $facets$county$Bedford
# [1] 3
#
# $facets$county$Derbyshire
# [1] 3
#
# $facets$county$Hertfordshire
# [1] 3
#
# $facets$county$Lancashire
# [1] 3
#
# $facets$county$`Milton Keynes`
# [1] 3
#
# $facets$county$`North Lincolnshire`
# [1] 3
#
# $facets$county$`North Yorkshire`
# [1] 3
#
# $facets$county$Worcestershire
# [1] 3
#
# $facets$county$`Greater London Authority`
# [1] 2
#
# $facets$county$`Isle of Anglesey`
# [1] 2
#
# $facets$county$Monmouthshire
# [1] 2
#
# $facets$county$Powys
# [1] 2
#
# $facets$county$Bournemouth
# [1] 1
#
# $facets$county$Carmarthenshire
# [1] 1
#
# $facets$county$`Central Bedfordshire`
# [1] 1
#
# $facets$county$`Cheshire East`
# [1] 1
#
# $facets$county$`Cheshire West and Chester`
# [1] 1
#
# $facets$county$`County Durham`
# [1] 1
#
# $facets$county$`North Somerset`
# [1] 1
#
# $facets$county$Northamptonshire
# [1] 1
#
# $facets$county$Pembrokeshire
# [1] 1
#
# $facets$county$Rutland
# [1] 1
#
# $facets$county$`South Gloucestershire`
# [1] 1
#
# $facets$county$Swansea
# [1] 1
#
# $facets$county$`Telford and Wrekin`
# [1] 1
#
# $facets$county$`Windsor and Maidenhead`
# [1] 1
#
#
# $facets$broadperiod
# $facets$broadperiod$`BRONZE AGE`
# [1] 387
#
#
# $facets$institution
# $facets$institution$HAMP
# [1] 27
#
# $facets$institution$CORN
# [1] 25
#
# $facets$institution$SUSS
# [1] 22
#
# $facets$institution$PAS
# [1] 21
#
# $facets$institution$IOW
# [1] 20
#
# $facets$institution$ESS
# [1] 19
#
# $facets$institution$KENT
# [1] 19
#
# $facets$institution$NMS
# [1] 19
#
# $facets$institution$WMID
# [1] 19
#
# $facets$institution$BERK
# [1] 18
#
# $facets$institution$NMGW
# [1] 17
#
# $facets$institution$WILT
# [1] 14
#
# $facets$institution$DOR
# [1] 13
#
# $facets$institution$LANCUM
# [1] 11
#
# $facets$institution$HESH
# [1] 10
#
# $facets$institution$SUR
# [1] 10
#
# $facets$institution$LVPL
# [1] 9
#
# $facets$institution$SF
# [1] 9
#
# $facets$institution$GLO
# [1] 8
#
# $facets$institution$BH
# [1] 7
#
# $facets$institution$BUC
# [1] 7
#
# $facets$institution$SOM
# [1] 7
#
# $facets$institution$WAW
# [1] 7
#
# $facets$institution$LIN
# [1] 6
#
# $facets$institution$YORYM
# [1] 6
#
# $facets$institution$CAM
# [1] 5
#
# $facets$institution$LEIC
# [1] 5
#
# $facets$institution$NLM
# [1] 5
#
# $facets$institution$DUR
# [1] 4
#
# $facets$institution$PUBLIC
# [1] 4
#
# $facets$institution$DENO
# [1] 3
#
# $facets$institution$NCL
# [1] 3
#
# $facets$institution$DEV
# [1] 2
#
# $facets$institution$SOMDOR
# [1] 2
#
# $facets$institution$SWYOR
# [1] 2
#
# $facets$institution$LON
# [1] 1
#
# $facets$institution$NARC
# [1] 1
#
#
# $facets$rulerName
# list()
#
# $facets$denominationName
# list()
#
# $facets$mintName
# list()
#
# $facets$materialTerm
# $facets$materialTerm$Gold
# [1] 263
#
# $facets$materialTerm$`Copper alloy`
# [1] 108
#
# $facets$materialTerm$Copper
# [1] 2
#
# $facets$materialTerm$`Jet or Shale`
# [1] 1
#
# $facets$materialTerm$Stone
# [1] 1
#
#
# $facets$workflow
# $facets$workflow$`3`
# [1] 236
#
# $facets$workflow$`4`
# [1] 151
#
#
# $facets$reeceID
# list()

# %% [markdown]
# 6. You can see at the top that there is some metadata related to the query results. We may need it later so we should grab it from the json file
#
# `total <- json$meta$totalResults`
#
# `results <- json$meta$resultsPerPage`
#
# `pagination <- ceiling(total/results)`

# %%
total <- json$meta$totalResults

results <- json$meta$resultsPerPage

pagination <- ceiling(total/results)

# %% [markdown]
# 7. This API brings back all of the data associated with all of the objects from our PAS query and that can be A LOT of information. If we're just interested in some of the variables for each objects we can limit those
#
# `keeps <- c("id", "objecttype", "old_findID", "broadperiod", "institution", "imagedir", "filename")`

# %%
keeps <- c("id", "objecttype", "old_findID", "broadperiod", "institution", "imagedir", "filename")

# %% [markdown]
# 8. We're then going make this limited data available from the json results of our API query and keep the columns we want.
#
# `data <- json$results`
#
# `data <- data[,(names(data) %in% keeps)]`

# %%
data <- json$results

data <- data[,(names(data) %in% keeps)]

# %% [markdown]
# 9. We can now look at the first part of the dataframe.
#
# `head(data)`

# %%
head(data)
# Out:
#   id     old_findID    objecttype   broadperiod institution filename
# 1 990381 WMID-0328FD   FLAT AXEHEAD BRONZE AGE  WMID        WMID0328FDcopy.jpg
# 2 973486 PAS-35C8A8    RIBBON       BRONZE AGE  PAS         2017T798a.jpg
# 3 971661 CORN-38B306   FLAT AXEHEAD BRONZE AGE  CORN        DSCN7955.JPG
# 4 968920 WMID-CF81FB   FLAT AXEHEAD BRONZE AGE  WMID        WMIDCF81FB.jpg
# 5 966940 CORN-5491C3   FLAT AXEHEAD BRONZE AGE  CORN        DSCN7806.JPG
# 6 962778 LANCUM-C6B5FC TORC         BRONZE AGE  LANCUM      LANCUMC6B5FC.jpg
#   imagedir
# 1 images/bobsure/
# 2 images/ianr/
# 3 images/atyacke/
# 4 images/tgilmore/
# 5 images/atyacke/
# 6 images/lydiaprosser/

# %% [markdown]
# 10. Now loop through all of the pages of results and bind it to a together in a single table. Since this is so much data, it may take a bit of time - be patient.
#
# `for (i in seq(from=2, to=pagination, by=1)){
#   urlDownload <- paste(url, '/page/', i, sep='')
#   pagedJson <- fromJSON(urlDownload)
#   records <- pagedJson$results
#   records <- records[,(names(records) %in% keeps)]
#   data <-rbind(data,records)
# }`

# %%
for (i in seq(from=2, to=pagination, by=1)){
  urlDownload <- paste(url, '/page/', i, sep='')
  pagedJson <- fromJSON(urlDownload)
  records <- pagedJson$results
  records <- records[,(names(records) %in% keeps)]
  data <-rbind(data,records)
}

# %% [markdown]
# 11. Finally, we can write this data table into a csv file. In this Jupyter file manager, download this csv file so you can upload it into your forked GitHub repo.
#
# `write.csv(data, file='data.csv',row.names=FALSE, na="")`

# %%
write.csv(data, file='data.csv',row.names=FALSE, na="")

# %% [markdown]
# 12. The last section of this notebook will focus on retrieving images from your original PAS query. Remember, in #7 you limited the attributes of the data you accessed with your query - this included the image directory and image file name. These next steps goes through the data you've already collected, creates a download path for the images, and saves the images to a file in an organized set of folders. First we're going to create a log file that will record any failures we encounter.
#
# `failures <- "failures.log"`
#
# `log_con <- file(failures)`

# %%
failures <- "failures.log"

log_con <- file(failures)

# %% [markdown]
# 13. Now make a function, which is a mini-program, that our R code can use over and over again to download the images. The following cell includes R code and script describing each section of the code. Try to follow each part of the code and understand what it means. You can just run the cell as is.

# %%
# Download function with test for URL
download <- function(data){
  # This should be the object type taken from column 3
  object = data[3]
  # This should be the record old find ID taken from column 2
  record = data[2]
  
  # Check and create a folder for that object type if does not exist
  if (!file.exists(object)){
    dir.create(object)
  }
  
  # Create image url - image path is in column 7 and filename is column 6
  URL = paste0(base,data[7],data[6])
  
  # Test the file exists
  exist <- url.exists(URL) 
  
  # If it does, download. If not say 404
  if(exist == TRUE){
    download.file(URLencode(URL), destfile = paste(object,basename(URL), sep = '/'))
  } else {
    print("That file is a 404")
    # Log the errors for sending back to PAS to fix - probably better than csv as you 
    # can tail -f and watch the errors come in
    message <- paste0(record,"|",URL,"|","404 \n")
    # Write to error file
    cat(message, file = failures, append = TRUE)
  }
}

# %% [markdown]
# 14. We're finally going to run the fuction, which will start downloading the images into newly created folders in your Jupyter file manager. To check on the status of this split your screen with this notebook on one side and the file manager on the other. What you will see when you run the code listed below are folders popping up in your file manager. You will also get some failed attempts to grab the image and below the code it may list "That file is a 404" which is what we told it to do (see the cell above this). You don't have to download all of the images in the dataset (that will take awhile), so after it runs for a few minutes press the square stop button in your notebook tool bar (next to the Run button). Go through some of the new folders the function has created in your file manager.
#
# `apply(data, 1, download)`

# %%
apply(data, 1, download)
# Out:
# [1] "That file is a 404"
